# %%
# !pip install tensorflow
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
X_OR=np.array([[0,0],[0,1],[1,0],[1,1]],dtype=np.float32)
y_OR=np.array([[0],[1],[1],[1]],dtype=np.float32)
X_XOR=np.array([[0,0],[0,1],[1,0],[1,1]],dtype=np.float32)
y_XOR=np.array([[0],[1],[1],[0]],dtype=np.float32)

# %%
import tensorflow as tf
def train_perceptron(X,y,epochs=100,learning_rate=0.1):
    model=tf.keras.Sequential([tf.keras.layers.Dense(1,activation='sigmoid',input_shape=(2,))])
    model.complie(optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),loss='binary_crossentropy',metrics=['accuracy'])
    model.fit(X,y,epochs=epochs,verbose=0)
    return model

# %%
model_OR=train_perceptron(X_OR,y_OR,epochs=500,learning_rate=0.5)
loss_OR,accuracy_OR=model_OR.evaluate(X_OR,y_OR)
print(f"OR gate accuracy:{accuracy_OR}")
model_XOR=train_perceptron(X_XOR,y_XOR,epochs=1000,learning_rate=0.8)
loss_XOR,accuracy_XOR=model_XOR.evaluate(X_XOR,y_XOR)
print(f"XOR gate accuracy:{accuracy_XOR}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 model_OR=train_perceptron(X_OR,y_OR,epochs=500,learning_rate=0.5)
#       2 loss_OR,accuracy_OR=model_OR.evaluate(X_OR,y_OR)
#       3 print(f"OR gate accuracy:{accuracy_OR}")
#
# Cell In[45], line 4, in train_perceptron(X, y, epochs, learning_rate)
#       2 def train_perceptron(X,y,epochs=100,learning_rate=0.1):
#       3     model=tf.keras.Sequential([tf.keras.layers.Dense(1,activation='sigmoid',input_shape=(2,))])
# ----> 4     model.complie(optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),loss='binary_crossentropy',metrics=['accuracy'])
#       5     model.fit(X,y,epochs=epochs,verbose=0)
#       6     return model
#
# AttributeError: 'Sequential' object has no attribute 'complie'

# %%
input1=0
input2=0
user_input=np.array([[input1,input2]])
prediction=model_OR.predict(user_input)
if prediction>0.5:
    print("the model predicts 1 for your input")
else:
    print("the model predits 0 for your input")
